# %% [markdown]
# # Avocado Project

# %% [markdown]
# importing required library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing Dataset

# %%
df=pd.read_csv('avocado_study.csv')
df
# Out:
#           Date  AveragePrice  Total Volume        4046        4225       4770  \
# 32  17-05-2015          0.98    5338992.15  2786200.82  1654563.98  108561.00
# 33  10-05-2015          0.94    6323724.80  3050014.63  2260890.88  115290.95
# 34  03-05-2015          0.89    6937095.53  3115937.71  2917083.83  104932.26
# 35  26-04-2015          0.90    6013312.36  3163353.08  2021745.62   79259.00
# 25  05-07-2015          0.78     913360.72   606650.91   123465.83   18233.51
# ..         ...           ...           ...         ...         ...        ...
# 10  16-10-2016          1.39     190846.01    57529.11    56366.66   17531.78
# 11  09-10-2016          1.51     178235.75    43325.87    52189.61   19419.57
# 12  02-10-2016          1.48     178410.82    46364.75    52893.38   16736.92
# 13  25-09-2016          1.47     189131.52    54110.79    53593.58   17495.42
# 14  18-09-2016          1.43     182978.30    43116.41    54193.42   16563.91
#
# ...

# %%
df.head()
# Out:
#           Date  AveragePrice  Total Volume        4046        4225       4770  \
# 32  17-05-2015          0.98    5338992.15  2786200.82  1654563.98  108561.00
# 33  10-05-2015          0.94    6323724.80  3050014.63  2260890.88  115290.95
# 34  03-05-2015          0.89    6937095.53  3115937.71  2917083.83  104932.26
# 35  26-04-2015          0.90    6013312.36  3163353.08  2021745.62   79259.00
# 25  05-07-2015          0.78     913360.72   606650.91   123465.83   18233.51
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 32   789666.35   608751.49   180702.04       212.82  conventional  2015
# 33   897528.34   678316.72   218968.93       242.69  conventional  2015
# 34   799141.73   611906.54   186891.82       343.37  conventional  2015
# 35   748954.66   614556.77   133326.40      1071.49  conventional  2015
# 25   165010.47   146199.35    18811.12         0.00  conventional  2015
#
#               region
# 32              West
# ...

# %%
df.tail()
# Out:
#           Date  AveragePrice  Total Volume      4046      4225      4770  \
# 10  16-10-2016          1.39     190846.01  57529.11  56366.66  17531.78
# 11  09-10-2016          1.51     178235.75  43325.87  52189.61  19419.57
# 12  02-10-2016          1.48     178410.82  46364.75  52893.38  16736.92
# 13  25-09-2016          1.47     189131.52  54110.79  53593.58  17495.42
# 14  18-09-2016          1.43     182978.30  43116.41  54193.42  16563.91
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 10    59418.46    48823.53    10354.65       240.28  conventional  2016
# 11    63300.70    54704.14     8596.56         0.00  conventional  2016
# 12    62415.77    53332.61     8258.16       825.00  conventional  2016
# 13    63931.73    55653.47     8278.26         0.00  conventional  2016
# 14    69104.56    57456.21    11648.35         0.00  conventional  2016
#
#        region
# 10  Charlotte
# 11  Charlotte
# 12  Charlotte
# 13  Charlotte
# 14  Charlotte

# %%
df.sample(10)
# Out:
#           Date  AveragePrice  Total Volume        4046        4225       4770  \
# 25  03-07-2016          1.30     180609.07     1424.51    85758.67      53.07
# 47  31-01-2016          0.94      83755.38    36196.35     4791.21    8440.95
# 35  24-04-2016          1.13     915500.04    61118.12   638833.81   15861.03
# 2   11-12-2016          0.80      98346.80    30311.25    10382.62    4088.10
# 21  31-07-2016          1.61     508949.60    12550.40   338691.73    8772.17
# 28  14-06-2015          0.70    1035973.14   651120.92   202731.92   13413.05
# 43  28-02-2016          1.12     888570.06    61483.80   641585.11   20335.44
# 30  29-05-2016          1.19     147423.25     1442.30    81631.15     353.83
# 38  03-04-2016          0.93    6060843.76  1805555.95  2247248.19  334735.17
# 4   27-11-2016          1.21    4185900.67  1508446.52  1313000.92   81897.44
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df.max()
# Out:
# Date                  31-07-2016
# AveragePrice                1.68
# Total Volume         10361698.17
# 4046                  3163353.08
# 4225                  3950852.38
# 4770                    424389.6
# Total Bags            3056112.91
# Small Bags            2693843.02
# Large Bags             508755.56
# XLarge Bags             41117.01
# type                conventional
# year                        2016
# region          WestTexNewMexico
# dtype: object

# %%
df.min()
# Out:
# Date              01-02-2015
# AveragePrice            0.58
# Total Volume        51941.45
# 4046                  467.72
# 4225                 1783.77
# 4770                     0.0
# Total Bags           6704.29
# Small Bags           6476.12
# Large Bags               0.0
# XLarge Bags              0.0
# type            conventional
# year                    2015
# region                Albany
# dtype: object

# %%
df.mean()
# Out:
# AveragePrice    1.110000e+00
# Total Volume    1.557944e+06
# 4046            5.165813e+05
# 4225            5.650082e+05
# 4770            5.586625e+04
# Total Bags      4.204884e+05
# Small Bags      3.778303e+05
# Large Bags      3.743431e+04
# XLarge Bags     5.223808e+03
# year            2.015888e+03
# dtype: float64

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.shape
# Out:
# (278, 13)

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isna().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 278 entries, 32 to 14
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          278 non-null    object
#  1   AveragePrice  278 non-null    float64
#  2   Total Volume  278 non-null    float64
#  3   4046          278 non-null    float64
#  4   4225          278 non-null    float64
#  5   4770          278 non-null    float64
#  6   Total Bags    278 non-null    float64
#  7   Small Bags    278 non-null    float64
#  8   Large Bags    278 non-null    float64
#  9   XLarge Bags   278 non-null    float64
#  10  type          278 non-null    object
#  11  year          278 non-null    int64
#  12  region        278 non-null    object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 30.4+ KB

# %% [markdown]
#  ## When Region is Target Variable

# %%
df['region'].unique()
# Out:
# array(['West', 'WestTexNewMexico', 'Albany', 'Atlanta',
#        'BaltimoreWashington', 'Boise', 'Boston', 'BuffaloRochester',
#        'California', 'Charlotte'], dtype=object)

# %%
df['region'].nunique()
# Out:
# 10

# %% [markdown]
# It shows that it is a multiclass classification problem

# %%
df['Date'].unique()
# Out:
# array(['17-05-2015', '10-05-2015', '03-05-2015', '26-04-2015',
#        '05-07-2015', '28-06-2015', '21-06-2015', '14-06-2015',
#        '07-06-2015', '31-05-2015', '24-05-2015', '19-04-2015',
#        '12-04-2015', '05-04-2015', '29-03-2015', '22-03-2015',
#        '15-03-2015', '08-03-2015', '01-03-2015', '22-02-2015',
#        '15-02-2015', '08-02-2015', '01-02-2015', '25-01-2015',
#        '18-01-2015', '11-01-2015', '04-01-2015', '25-12-2016',
#        '18-12-2016', '11-12-2016', '04-12-2016', '27-11-2016',
#        '20-11-2016', '13-11-2016', '06-11-2016', '30-10-2016',
#        '23-10-2016', '16-10-2016', '09-10-2016', '02-10-2016',
#        '25-09-2016', '18-09-2016', '08-05-2016', '01-05-2016',
#        '24-04-2016', '17-04-2016', '10-04-2016', '03-04-2016',
#        '27-03-2016', '20-03-2016', '13-03-2016', '06-03-2016',
#        '28-02-2016', '21-02-2016', '14-02-2016', '07-02-2016',
#        '31-01-2016', '12-06-2016', '05-06-2016', '29-05-2016',
# ...

# %%
df['Date'].nunique()
# Out:
# 79

# %%
df['AveragePrice'].unique()
# Out:
# array([0.98, 0.94, 0.89, 0.9 , 0.78, 0.71, 0.74, 0.7 , 0.68, 0.75, 0.76,
#        0.85, 0.73, 0.84, 0.72, 0.8 , 0.92, 1.52, 1.53, 1.49, 1.48, 1.56,
#        1.62, 1.63, 1.46, 1.19, 1.4 , 1.13, 1.51, 1.39, 0.81, 0.77, 0.79,
#        0.83, 1.03, 1.04, 0.97, 1.34, 1.33, 1.12, 0.95, 1.07, 1.14, 1.1 ,
#        1.18, 1.21, 1.2 , 1.11, 1.09, 1.17, 1.02, 1.01, 1.22, 1.27, 1.28,
#        1.37, 0.91, 0.99, 0.65, 0.58, 0.61, 0.63, 0.67, 0.82, 0.86, 0.93,
#        1.26, 1.45, 1.41, 1.31, 1.29, 1.61, 1.32, 1.38, 1.08, 1.05, 1.06,
#        1.15, 1.36, 1.47, 1.66, 1.57, 1.6 , 1.5 , 1.44, 1.3 , 1.25, 1.23,
#        1.35, 1.68, 0.96, 0.88, 0.87, 1.24, 1.54, 1.64, 1.58, 1.43])

# %%
df['AveragePrice'].nunique()
# Out:
# 98

# %%
df['Total Volume'].unique()
# Out:
# array([ 5338992.15,  6323724.8 ,  6937095.53,  6013312.36,   913360.72,
#          941135.5 ,   948942.53,  1035973.14,  1053997.99,   887045.15,
#          914966.82,   942310.32,  1019160.83,   967144.19,   899632.66,
#          961001.34,   840314.58,   938880.6 ,   908323.3 ,   752576.08,
#          827795.25,   805731.03,   723488.95,   681409.59,   743066.25,
#          811664.36,   916367.42,   720800.61,   729795.72,   584896.99,
#          758118.95,    73341.73,    68938.53,    71777.85,   113031.96,
#           58171.89,    70089.51,    63608.01,    57178.2 ,    58375.1 ,
#           92080.35,    69060.9 ,   101087.84,    75480.26,    96853.15,
#           79513.63,   643699.77,   735635.49,   654018.81,   512348.02,
#          590001.82,   423485.95,   458635.34,   496190.99,   588656.86,
#          458837.18,   555470.58,   417205.77,   481484.29,   722211.  ,
#          437490.64,   850862.92,   860858.18,   890196.73,   837573.29,
# ...

# %%
df['Total Volume'].nunique()
# Out:
# 278

# %%
df['4046'].unique()
# Out:
# array([2.78620082e+06, 3.05001463e+06, 3.11593771e+06, 3.16335308e+06,
#        6.06650910e+05, 6.70425340e+05, 6.01318240e+05, 6.51120920e+05,
#        7.50594500e+05, 6.26724730e+05, 6.92900550e+05, 7.21087660e+05,
#        7.74232700e+05, 6.77575960e+05, 5.96342410e+05, 6.87794590e+05,
#        5.64694430e+05, 6.60961680e+05, 5.95240910e+05, 4.89678550e+05,
#        6.10496240e+05, 5.68182300e+05, 4.39115270e+05, 4.55087170e+05,
#        5.20464290e+05, 5.39280410e+05, 6.11270390e+05, 5.19142820e+05,
#        5.16446410e+05, 3.47125630e+05, 4.26878870e+05, 3.20239000e+03,
#        3.34536000e+03, 2.32339000e+03, 6.53078000e+03, 2.79399000e+03,
#        3.67563000e+03, 3.52363000e+03, 3.21204000e+03, 3.18714000e+03,
#        4.22293000e+03, 4.02742000e+03, 3.64146000e+03, 4.10922000e+03,
#        7.65855000e+03, 6.62437000e+03, 1.99995470e+05, 2.41665170e+05,
#        2.33878100e+05, 1.90569750e+05, 2.58662260e+05, 2.53540830e+05,
# ...

# %%
df['4046'].nunique()
# Out:
# 278

# %%
df['4225'].unique()
# Out:
# array([1.65456398e+06, 2.26089088e+06, 2.91708383e+06, 2.02174562e+06,
#        1.23465830e+05, 1.08019800e+05, 1.58997230e+05, 2.02731920e+05,
#        1.52736510e+05, 1.24037260e+05, 1.07964220e+05, 1.12070950e+05,
#        1.28168650e+05, 1.66456050e+05, 1.74560730e+05, 1.54971840e+05,
#        1.67105740e+05, 1.63481600e+05, 1.99938300e+05, 1.57679620e+05,
#        1.15089700e+05, 1.37012170e+05, 1.67245850e+05, 1.21269480e+05,
#        1.33695540e+05, 1.75207310e+05, 2.05181230e+05, 1.24248860e+05,
#        1.28438870e+05, 1.29717420e+05, 1.47958430e+05, 5.82803300e+04,
#        5.59497900e+04, 5.65457900e+04, 9.97460500e+04, 4.71061800e+04,
#        5.68985400e+04, 4.98376800e+04, 4.30243200e+04, 4.58985200e+04,
#        7.75373600e+04, 5.41865500e+04, 8.71744100e+04, 5.75157600e+04,
#        7.94258100e+04, 6.33845600e+04, 1.59036970e+05, 2.11776980e+05,
#        1.89043440e+05, 1.24409160e+05, 1.41605690e+05, 6.93274400e+04,
# ...

# %%
df['4225'].nunique()
# Out:
# 278

# %%
df['4770'].unique()
# Out:
# array([1.0856100e+05, 1.1529095e+05, 1.0493226e+05, 7.9259000e+04,
#        1.8233510e+04, 1.3077850e+04, 1.3455470e+04, 1.3413050e+04,
#        1.2543430e+04, 2.5328560e+04, 1.4654280e+04, 1.2170590e+04,
#        1.3889830e+04, 1.5065010e+04, 1.4468890e+04, 1.6243480e+04,
#        1.1290940e+04, 1.5530040e+04, 1.8570600e+04, 1.4084250e+04,
#        1.3114910e+04, 1.2344540e+04, 2.8226160e+04, 1.6470860e+04,
#        1.2099880e+04, 1.3717570e+04, 1.4107360e+04, 1.0573290e+04,
#        1.2473140e+04, 2.7944070e+04, 1.5267890e+04, 4.2692000e+02,
#        1.3872000e+02, 8.6650000e+01, 5.0840000e+01, 1.8140000e+01,
#        1.1000000e+01, 3.4000000e+01, 3.6400000e+01, 5.4310000e+01,
#        4.6000000e+01, 5.3770000e+01, 1.0215000e+02, 8.4080000e+01,
#        4.3250000e+01, 3.7480000e+01, 2.5352000e+02, 5.4420000e+01,
#        6.7420000e+01, 1.0639000e+02, 4.3250000e+02, 1.3491800e+03,
#        1.3200200e+03, 1.7271100e+03, 1.9069000e+03, 1.4994000e+03,
# ...

# %%
df['4770'].nunique()
# Out:
# 278

# %%
df['Total Bags'].unique()
# Out:
# array([ 789666.35,  897528.34,  799141.73,  748954.66,  165010.47,
#         149612.51,  175171.59,  168707.25,  138123.55,  110954.6 ,
#          99447.77,   96981.12,  102869.65,  108047.17,  114260.63,
#         101991.43,   97223.47,   98907.28,   94573.49,   91133.66,
#          89094.4 ,   88192.02,   88901.67,   88582.08,   76806.54,
#          83459.07,   85808.44,   66835.64,   72437.3 ,   80109.87,
#         168013.76,   11432.09,    9504.66,   12822.02,    6704.29,
#           8253.58,    9504.34,   10212.7 ,   10905.44,    9235.13,
#          10274.06,   10793.16,   10169.82,   13771.2 ,    9725.54,
#           9467.22,  284413.81,  282138.92,  231029.85,  197262.72,
#         189301.37,   99268.5 ,  111106.99,  110119.55,  140293.7 ,
#          95584.31,  122138.09,   83444.96,  109208.77,  171633.14,
#          87653.  ,  214114.58,  215173.44,  206607.44,  216401.98,
#         196639.52,  207324.76,  197919.93,  199687.08,  189898.78,
# ...

# %%
df['Total Bags'].nunique()
# Out:
# 278

# %%
df['Small Bags'].unique()
# Out:
# array([ 608751.49,  678316.72,  611906.54,  614556.77,  146199.35,
#         130392.24,  148132.78,  126508.62,  103719.2 ,   78423.65,
#          82335.29,   74460.15,   79189.32,   80711.69,   80697.34,
#          76595.17,   71587.33,   91530.77,   88599.82,   89232.98,
#          86399.27,   85848.21,   86800.97,   86050.77,   73763.41,
#          81116.25,   82065.7 ,   65072.69,   71564.22,   78503.46,
#         165202.22,   11017.32,    8876.65,   12176.75,    6476.12,
#           7973.98,    9238.4 ,    9790.67,   10474.09,    9153.12,
#          10160.26,   10434.39,    9744.41,   13345.52,    9586.8 ,
#           8958.14,   77087.9 ,   64801.33,   71926.92,   66461.65,
#          69497.05,   62657.11,   78824.96,   75568.52,   73593.38,
#          62105.43,   60231.13,   55736.39,   74366.38,   77183.81,
#          54822.3 ,  207727.87,  203788.41,  200150.21,  211306.25,
#         189850.35,  204118.09,  194073.11,  196063.01,  185709.01,
# ...

# %%
df['Total Bags'].nunique()
# Out:
# 278

# %%
df['XLarge Bags'].unique()
# Out:
# array([2.128200e+02, 2.426900e+02, 3.433700e+02, 1.071490e+03,
#        0.000000e+00, 2.940000e+00, 4.028000e+01, 5.694000e+01,
#        8.814000e+02, 1.833300e+02, 5.832600e+02, 7.665000e+02,
#        1.361000e+01, 2.935000e+03, 3.056110e+03, 2.741110e+03,
#        2.145000e+03, 5.944400e+02, 5.152800e+02, 6.027800e+02,
#        4.916700e+02, 1.155560e+03, 1.925000e+01, 4.820000e+00,
#        5.468000e+01, 1.288000e+01, 1.127000e+01, 4.030000e+01,
#        1.032600e+02, 9.361000e+01, 1.452000e+01, 1.129000e+01,
#        2.417000e+01, 3.380000e+01, 4.810000e+00, 6.390000e+00,
#        7.980000e+00, 7.960000e+00, 1.588000e+01, 1.820000e+01,
#        6.450000e+01, 3.470000e+01, 1.815000e+01, 6.580000e+00,
#        5.858300e+02, 8.943000e+01, 8.080000e+00, 2.726000e+01,
#        1.115000e+01, 3.649000e+01, 1.740000e+01, 2.053000e+01,
#        6.310000e+00, 9.470000e+00, 6.946000e+01, 3.328300e+02,
#        1.896000e+01, 7.920000e+00, 6.513000e+01, 3.667000e+01,
# ...

# %%
df['XLarge Bags'].nunique()
# Out:
# 157

# %%
df['type'].unique()
# Out:
# array(['conventional'], dtype=object)

# %%
df['type'].nunique()
# Out:
# 1

# %%
df['year'].unique()
# Out:
# array([2015, 2016], dtype=int64)

# %%
df['year'].nunique()
# Out:
# 2

# %% [markdown]
# It shows that it is a multiclass classification problem

# %%
#Counting the unique values in each column
for i in df.columns:
    value_counts=df[i].value_counts()
    print('\n')
    print(value_counts)
# Out:
# 21-02-2016    6
# 20-11-2016    6
# 14-02-2016    6
# 13-03-2016    6
# 28-02-2016    6
#              ..
# 08-03-2015    1
# 01-03-2015    1
# 22-02-2015    1
# 15-02-2015    1
# 05-04-2015    1
# Name: Date, Length: 79, dtype: int64
#
#
# 0.90    9
# 0.94    7
# 0.98    6
# 1.08    6
# 1.10    6
#        ..
# 0.72    1
# 1.18    1
# 1.53    1
# 1.49    1
# 1.43    1
# Name: AveragePrice, Length: 98, dtype: int64
#
#
# 5338992.15    1
# 183741.31     1
# 147423.25     1
# 173445.42     1
# 182471.54     1
#              ..
# 87557.13      1
# 82377.77      1
# 89822.98      1
# 79683.06      1
# 182978.30     1
# Name: Total Volume, Length: 278, dtype: int64
#
#
# 2786200.82    1
# 1425.12       1
# 1442.30       1
# 1451.17       1
# 4629.34       1
#              ..
# 39342.09      1
# 39719.19      1
# 41793.11      1
# 37233.67      1
# 43116.41      1
# Name: 4046, Length: 278, dtype: int64
#
#
# 1654563.98    1
# 88105.93      1
# 81631.15      1
# 78923.00      1
# ...

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225           4770  \
# count    278.000000  2.780000e+02  2.780000e+02  2.780000e+02     278.000000
# mean       1.110000  1.557944e+06  5.165813e+05  5.650082e+05   55866.248669
# std        0.260918  2.365204e+06  8.613313e+05  7.905209e+05   98860.891194
# min        0.580000  5.194145e+04  4.677200e+02  1.783770e+03       0.000000
# 25%        0.900000  1.308289e+05  5.142875e+03  5.640438e+04    1327.310000
# 50%        1.095000  5.834601e+05  4.173537e+04  1.538542e+05   12663.940000
# 75%        1.310000  9.222377e+05  6.000743e+05  5.726851e+05   47740.225000
# max        1.680000  1.036170e+07  3.163353e+06  3.950852e+06  424389.600000
#
#          Total Bags    Small Bags     Large Bags  XLarge Bags         year
# count  2.780000e+02  2.780000e+02     278.000000    278.00000   278.000000
# mean   4.204884e+05  3.778303e+05   37434.308669   5223.80795  2015.888489
# ...

# %% [markdown]
# Key Observations
#
# The columns looks good as there are no invalid or negetive values present as well no null and nan values.
# In 4046,4255,4770,large bags and xlarge bags column the mean is greater than the 50% of the data indicating the datas are right skewed.
# The Std deviation of 4770,Large,xlarge columns are very high indicating the datas are widely spread.
# The difference between 75% and max values in 4770,Large bags and Xlarge bags columns are very high indicating the presence of outliers.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# univariate Analysis

# %%
sns.histplot(df['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Count'>

# %%
sns.stripplot(df['4046'])
# Out:
# <AxesSubplot:xlabel='4046'>

# %%
sns.histplot(df['4225'])
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Count'>

# %%
sns.histplot(df['4770'])
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Count'>

# %%
sns.histplot(df['Total Bags'])
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Count'>

# %%
sns.histplot(df['Small Bags'])
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Count'>

# %%
sns.stripplot(df['Large Bags'])
# Out:
# <AxesSubplot:xlabel='Large Bags'>

# %%
sns.stripplot(df['XLarge Bags'])
# Out:
# <AxesSubplot:xlabel='XLarge Bags'>

# %%
sns.histplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
sns.stripplot(df['type'])
# Out:
# <AxesSubplot:xlabel='type'>

# %%
sns.histplot(df['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='Count'>

# %%
sns.histplot(df['Date'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Count'>

# %%
sns.histplot(df['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Count'>

# %% [markdown]
# Bivariate Analaysis

# %%
sns.barplot(x='Total Volume',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='region'>

# %%
sns.barplot(x='4046',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='region'>

# %%
sns.barplot(x='4225',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='4225', ylabel='region'>

# %%
sns.barplot(x='4770',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='4770', ylabel='region'>

# %%
sns.barplot(x='Total Bags',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='region'>

# %%
sns.stripplot(x='Small Bags',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='region'>

# %%
sns.scatterplot(x='Large Bags',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='region'>

# %%
sns.barplot(x='XLarge Bags',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='region'>

# %%
sns.stripplot(x='Date',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='region'>

# %%
sns.barplot(x='AveragePrice',y='region',data=df)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='region'>

# %% [markdown]
# Multivariate Analysis

# %%
# Reset the index of the DataFrame
df.reset_index(drop=True, inplace=True)

# Create the pair plot
sns.pairplot(df)

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# we can see that we have date, type and region are our categorical columns with object data type and rest columns are numerical datatype.so we will encode the categorical columns and drop the unnecessary columns like date

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.240931 -0.290754 -0.191275 -0.223855
# Total Volume     -0.240931      1.000000  0.967480  0.979114  0.917826
# 4046             -0.290754      0.967480  1.000000  0.915163  0.847525
# 4225             -0.191275      0.979114  0.915163  1.000000  0.897468
# 4770             -0.223855      0.917826  0.847525  0.897468  1.000000
# Total Bags       -0.213278      0.974042  0.904804  0.946539  0.923499
# Small Bags       -0.193919      0.968462  0.897156  0.941236  0.917385
# Large Bags       -0.337885      0.797482  0.757096  0.775682  0.768721
# XLarge Bags      -0.037368      0.854930  0.817106  0.818573  0.765409
# year              0.449753      0.002204 -0.159798  0.067684  0.104856
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.213278   -0.193919   -0.337885    -0.037368  0.449753
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Key Observatio
#
# We can see that Date average price and year columns are negetively correlated to target variable region.
# Other columns show moderate positive correlation with target variable.

# %% [markdown]
# ### Plotting Outliers

# %%
plt.boxplot(df['Total Volume'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2690ed27940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2690ed27ee0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2690ed27790>],
#  'medians': [<matplotlib.lines.Line2D at 0x2690ed374c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2690ed37790>],
#  'means': []}

# %%
plt.boxplot(df['4046'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2690e994280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2690e994820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2690e984f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x2690e994dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2690e9a40d0>],
#  'means': []}

# %%
plt.boxplot(df['4225'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2690e9f2850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2690e9f2df0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2690e9f26a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2690ea003d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2690ea006a0>],
#  'means': []}

# %%
plt.boxplot(df['4770'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2690ea58a60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2690ea67040>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2690ea588b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2690ea675e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2690ea678b0>],
#  'means': []}

# %%
plt.boxplot(df['Total Bags'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2690eafb5e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2690eafbb80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2690eafb430>],
#  'medians': [<matplotlib.lines.Line2D at 0x2690eb06160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2690eb06430>],
#  'means': []}

# %%
plt.boxplot(df['Small Bags'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2690eb54df0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2690eb643d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2690eb45a00>],
#  'medians': [<matplotlib.lines.Line2D at 0x2690eb64970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2690eb64c40>],
#  'means': []}

# %%
plt.boxplot(df['Large Bags'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2690ebb5e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2690ebc7460>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2690ebb5bb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2690ebc7a00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2690ebc7cd0>],
#  'means': []}

# %%
plt.boxplot(df['XLarge Bags'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2690ec26280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2690ec26820>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2690ec16f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x2690ec26dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2690ff950d0>],
#  'means': []}

# %%
plt.boxplot(df['year'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2690ffdbb50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2690ffec130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2690ffdb880>],
#  'medians': [<matplotlib.lines.Line2D at 0x2690ffec6d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2690ffec9a0>],
#  'means': []}

# %%
plt.boxplot(df['AveragePrice'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2691017bca0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2691018c280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2691017b9d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2691018c820>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2691018caf0>],
#  'means': []}

# %% [markdown]
# ### Detecting Skewness

# %%
df.skew()
# Out:
# AveragePrice    0.227343
# Total Volume    1.616285
# 4046            1.609595
# 4225            1.589596
# 4770            2.120266
# Total Bags      1.789303
# Small Bags      1.773662
# Large Bags      3.029740
# XLarge Bags     1.933999
# year           -2.481862
# dtype: float64

# %%
sns.distplot(df['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.distplot(df['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %%
sns.distplot(df['4046'])
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Density'>

# %%
sns.distplot(df['4225'])
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Density'>

# %%
sns.distplot(df['4770'])
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Density'>

# %%
sns.distplot(df['Total Bags'])
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
sns.distplot(df['Small Bags'])
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Density'>

# %%
sns.distplot(df['Large Bags'])
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Density'>

# %%
sns.distplot(df['XLarge Bags'])
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Density'>

# %%
sns.distplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %% [markdown]
# Even after we find the presence of outliers and skewness in the dataset we wont remove them as our dataset is very small and removal of them will result in loss in data.
#  So instead we will move ahead with feature engineering

# %% [markdown]
# ## Encoding Categorical Columns

# %%
from sklearn.preprocessing import LabelEncoder
categorical_cols = df.select_dtypes(include=['object']).columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
df.dtypes
# Out:
# Date              int32
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# dtype: object

# %% [markdown]
# ### Separating features and labels

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
# here we are sepearating our target variable from independent /feature variables
x=df.drop('region',axis=1)
y=df['region']

# %%
x
# Out:
#     Date  AveragePrice  Total Volume        4046        4225       4770  \
# 32    43          0.98    5338992.15  2786200.82  1654563.98  108561.00
# 33    25          0.94    6323724.80  3050014.63  2260890.88  115290.95
# 34     6          0.89    6937095.53  3115937.71  2917083.83  104932.26
# 35    66          0.90    6013312.36  3163353.08  2021745.62   79259.00
# 25    13          0.78     913360.72   606650.91   123465.83   18233.51
# ..   ...           ...           ...         ...         ...        ...
# 10    40          1.39     190846.01    57529.11    56366.66   17531.78
# 11    22          1.51     178235.75    43325.87    52189.61   19419.57
# 12     3          1.48     178410.82    46364.75    52893.38   16736.92
# 13    64          1.47     189131.52    54110.79    53593.58   17495.42
# 14    46          1.43     182978.30    43116.41    54193.42   16563.91
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags  type  year
# ...

# %%
x.dtypes
# Out:
# Date              int32
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# dtype: object

# %%
y
# Out:
# 32    8
# 33    8
# 34    8
# 35    8
# 25    9
#      ..
# 10    7
# 11    7
# 12    7
# 13    7
# 14    7
# Name: region, Length: 278, dtype: int32

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
xs=scale.fit_transform(x)
x1_s=scale.fit_transform(x)

# %%
xs.shape
# Out:
# (278, 12)

# %%
x1_s.shape
# Out:
# (278, 12)

# %% [markdown]
# Here in fit method we are giving the data onthe method and the method will do diffenent analysis, it will find out relationship pattern and then we are using transform methos which will on the basis of previous learning the data will be changed
#
# We have scaled the data using Standard Scalarization method to overcome the issue of biasness

# %%
y.value_counts()
# Out:
# 6    52
# 4    44
# 5    42
# 3    40
# 9    27
# 2    24
# 0    15
# 1    15
# 7    15
# 8     4
# Name: region, dtype: int64

# %% [markdown]
# It is a problem of linear regression

# %% [markdown]
# ### train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=47)

# %%
x_train.shape
# Out:
# (222, 12)

# %%
x_test.shape
# Out:
# (56, 12)

# %%
y_train.shape
# Out:
# (222,)

# %%
y_test.shape
# Out:
# (56,)

# %% [markdown]
# ## Model Building

# %% [markdown]
# Finding the best random state

# %%
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

# %%
#Finding the maximum accuracy
maxAccu=0
ln=LinearRegression()
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    mod=ln
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('the best accuracy is ',maxAccu,'on random state',maxRS)
# Out:
# the best accuracy is  0.7630858796097921 on random state 2

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
print('x train shape:',x_train.shape)
print('x test shape',x_test.shape)
print('\n')
print('y train shape:',y_train.shape)
print('y test shape',y_test.shape)
# Out:
# x train shape: (194, 12)
# x test shape (84, 12)
#
#
# y train shape: (194,)
# y test shape (84,)

# %%
#linear model
ln=LinearRegression()
ln.fit(x_train,y_train)
predln=ln.predict(x_test)
print('r2 score is :',round((r2_score(y_test,predln)),3))
print('RMSE:',round(np.sqrt(mean_squared_error(y_test,predln)),3))
print('mean absolute error:',round((mean_absolute_error(y_test,predln)),3))
# Out:
# r2 score is : 0.763
# RMSE: 1.158
# mean absolute error: 0.782

# %%
rf = RandomForestRegressor(n_estimators=1000)
rf.fit(x_train, y_train)
predrf=rf.predict(x_test)
print('r2 score is :',round((r2_score(y_test,predrf)),3))
print('RMSE:',round(np.sqrt(mean_squared_error(y_test,predrf)),3))
print('mean absolute error:',round((mean_absolute_error(y_test,predrf)),3))
# Out:
# r2 score is : 0.739
# RMSE: 1.217
# mean absolute error: 0.315

# %%
et = ExtraTreesRegressor(n_estimators=1000)
et.fit(x_train, y_train)
predet=et.predict(x_test)
print('r2 score is :',round((r2_score(y_test,predet)),3))
print('RMSE:',round(np.sqrt(mean_squared_error(y_test,predet)),3))
print('mean absolute error:',round((mean_absolute_error(y_test,predet)),3))
# Out:
# r2 score is : 0.969
# RMSE: 0.421
# mean absolute error: 0.114

# %%
gb = GradientBoostingRegressor(n_estimators=1000)
gb.fit(x_train, y_train)
predgb=gb.predict(x_test)
print('r2 score is :',round((r2_score(y_test,predgb)),3))
print('RMSE:',round(np.sqrt(mean_squared_error(y_test,predgb)),3))
print('mean absolute error:',round((mean_absolute_error(y_test,predgb)),3))
# Out:
# r2 score is : 0.77
# RMSE: 1.141
# mean absolute error: 0.33

# %% [markdown]
# ### Cross validation score

# %%
models=[ln,rf,et,gb]
for m in models:
    
    score=cross_val_score(m,xs,y,cv=5)
    print(m,'score is:')
    print(round((score.mean()),3))
    print('\n')
# Out:
# LinearRegression() score is:
# -1.9583371903625896e+23
#
#
# RandomForestRegressor(n_estimators=1000) score is:
# -23.445
#
#
# ExtraTreesRegressor(n_estimators=1000) score is:
# -9.265
#
#
# GradientBoostingRegressor(n_estimators=1000) score is:
# -17.226

# %% [markdown]
# ### Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
rf=RandomForestRegressor()
grid_param={
    'n_estimators':[10,25,50,75],
    'criterion':['mse','mae'],
    'max_features':['auto','sqrt'],
    'min_samples_split':[2, 5, 10, 15],
    'min_samples_leaf':[1, 2, 5, 10]
}

gd_sr=GridSearchCV(estimator=rf,
                  param_grid=grid_param,
                  scoring='r2',
                  cv=5)

gd_sr.fit(xs,y)

best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 10}
# -6.710736387326525

# %%
rf1=RandomForestRegressor(n_estimators=10,criterion='mae',max_features='sqrt',min_samples_split=10,min_samples_leaf=2)

# %%
rf1.fit(x_train, y_train)
predrf1=rf1.predict(x_test)
print('r2 score is :',round((r2_score(y_test,predrf1)),3))
print('RMSE:',round(np.sqrt(mean_squared_error(y_test,predrf1)),3))
print('mean absolute error:',round((mean_absolute_error(y_test,predrf1)),3))
# Out:
# r2 score is : 0.849
# RMSE: 0.925
# mean absolute error: 0.46

# %% [markdown]
# The Maximum Accuracy we got is 0.954

# %%
new_data = np.array(y_test)
new_predictions = np.array(rf1.predict(x_test))
Avocado_region = pd.DataFrame({"Original":new_data,"Predicted":new_predictions}, index=range(len(new_data)))
print(Avocado_region)
# Out:
#     Original  Predicted
# 0          4       3.70
# 1          9       6.60
# 2          3       3.00
# 3          9       9.00
# 4          3       3.80
# ..       ...        ...
# 79         9       8.30
# 80         6       6.00
# 81         3       4.40
# 82         9       8.75
# 83         6       6.00
#
# [84 rows x 2 columns]

# %% [markdown]
# ## Saving the model

# %%
import joblib
joblib.dump(rf1,'rf1avacado.obj')
# Out:
# ['rf1avacado.obj']

# %% [markdown]
# ## WHEN AVERAGE PRICE IS TARGET VARIABLE

# %%
df1=pd.read_csv('avocado_study.csv')
df1
# Out:
#           Date  AveragePrice  Total Volume        4046        4225       4770  \
# 32  17-05-2015          0.98    5338992.15  2786200.82  1654563.98  108561.00
# 33  10-05-2015          0.94    6323724.80  3050014.63  2260890.88  115290.95
# 34  03-05-2015          0.89    6937095.53  3115937.71  2917083.83  104932.26
# 35  26-04-2015          0.90    6013312.36  3163353.08  2021745.62   79259.00
# 25  05-07-2015          0.78     913360.72   606650.91   123465.83   18233.51
# ..         ...           ...           ...         ...         ...        ...
# 10  16-10-2016          1.39     190846.01    57529.11    56366.66   17531.78
# 11  09-10-2016          1.51     178235.75    43325.87    52189.61   19419.57
# 12  02-10-2016          1.48     178410.82    46364.75    52893.38   16736.92
# 13  25-09-2016          1.47     189131.52    54110.79    53593.58   17495.42
# 14  18-09-2016          1.43     182978.30    43116.41    54193.42   16563.91
#
# ...

# %%
df1
# Out:
#           Date  AveragePrice  Total Volume        4046        4225       4770  \
# 32  17-05-2015          0.98    5338992.15  2786200.82  1654563.98  108561.00
# 33  10-05-2015          0.94    6323724.80  3050014.63  2260890.88  115290.95
# 34  03-05-2015          0.89    6937095.53  3115937.71  2917083.83  104932.26
# 35  26-04-2015          0.90    6013312.36  3163353.08  2021745.62   79259.00
# 25  05-07-2015          0.78     913360.72   606650.91   123465.83   18233.51
# ..         ...           ...           ...         ...         ...        ...
# 10  16-10-2016          1.39     190846.01    57529.11    56366.66   17531.78
# 11  09-10-2016          1.51     178235.75    43325.87    52189.61   19419.57
# 12  02-10-2016          1.48     178410.82    46364.75    52893.38   16736.92
# 13  25-09-2016          1.47     189131.52    54110.79    53593.58   17495.42
# 14  18-09-2016          1.43     182978.30    43116.41    54193.42   16563.91
#
# ...

# %% [markdown]
# Univariate Analysis

# %%
sns.histplot(df1['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Count'>

# %%
sns.histplot(df1['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Count'>

# %%
sns.histplot(df1['4046'])
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Count'>

# %%
sns.histplot(df1['4225'])
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Count'>

# %%
sns.histplot(df1['4770'])
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Count'>

# %%
sns.histplot(df1['Total Bags'])
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Count'>

# %%
sns.histplot(df1['Small Bags'])
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Count'>

# %%
sns.histplot(df1['Large Bags'])
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Count'>

# %%
sns.histplot(df1['XLarge Bags'])
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Count'>

# %%
sns.histplot(df1['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='Count'>

# %%
sns.histplot(df1['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
sns.histplot(df1['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='Count'>

# %% [markdown]
# Bivariate Analysis

# %%
sns.barplot(x='Total Volume',y='AveragePrice',data=df1)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='AveragePrice'>

# %%
sns.barplot(x='4225',y='AveragePrice',data=df1)
# Out:
# <AxesSubplot:xlabel='4225', ylabel='AveragePrice'>

# %%
sns.barplot(x='AveragePrice',y='4046',data=df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='4046'>

# %%
sns.barplot(x='AveragePrice',y='4770',data=df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='4770'>

# %%
sns.barplot(x='AveragePrice',y='Total Bags',data=df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Bags'>

# %%
sns.barplot(x='AveragePrice',y='Small Bags',data=df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Small Bags'>

# %%
sns.barplot(x='AveragePrice',y='Large Bags',data=df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Large Bags'>

# %%
sns.barplot(x='AveragePrice',y='Large Bags',data=df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Large Bags'>

# %%
sns.barplot(x='AveragePrice',y='XLarge Bags',data=df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='XLarge Bags'>

# %%
sns.barplot(x='type',y='AveragePrice',data=df1)
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %%
sns.barplot(x='AveragePrice',y='year',data=df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='year'>

# %%
sns.barplot(x='AveragePrice',y='region',data=df1)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='region'>

# %% [markdown]
# Multivariate Analysis

# %%
# Reset the index of the DataFrame
df1.reset_index(drop=True, inplace=True)

# Create the pair plot
sns.pairplot(df1)

# %%
corr=df1.corr()
corr
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.240931 -0.290754 -0.191275 -0.223855
# Total Volume     -0.240931      1.000000  0.967480  0.979114  0.917826
# 4046             -0.290754      0.967480  1.000000  0.915163  0.847525
# 4225             -0.191275      0.979114  0.915163  1.000000  0.897468
# 4770             -0.223855      0.917826  0.847525  0.897468  1.000000
# Total Bags       -0.213278      0.974042  0.904804  0.946539  0.923499
# Small Bags       -0.193919      0.968462  0.897156  0.941236  0.917385
# Large Bags       -0.337885      0.797482  0.757096  0.775682  0.768721
# XLarge Bags      -0.037368      0.854930  0.817106  0.818573  0.765409
# year              0.449753      0.002204 -0.159798  0.067684  0.104856
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.213278   -0.193919   -0.337885    -0.037368  0.449753
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(corr,cmap='Greens',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Key Observations
#
# We can see that year column is only ppositively correlating with Target Variable and rest of the columns are negetively correlating with target variable.

# %% [markdown]
# ### outliers Removal

# %%
sns.boxplot(df1['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice'>

# %%
sns.boxplot(df1['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume'>

# %%
sns.boxplot(df1['4046'])
# Out:
# <AxesSubplot:xlabel='4046'>

# %%
sns.boxplot(df1['4225'])
# Out:
# <AxesSubplot:xlabel='4225'>

# %%
sns.boxplot(df1['4770'])
# Out:
# <AxesSubplot:xlabel='4770'>

# %%
sns.boxplot(df1['Total Bags'])
# Out:
# <AxesSubplot:xlabel='Total Bags'>

# %%
sns.boxplot(df1['Small Bags'])
# Out:
# <AxesSubplot:xlabel='Small Bags'>

# %%
sns.boxplot(df1['Large Bags'])
# Out:
# <AxesSubplot:xlabel='Large Bags'>

# %%
sns.boxplot(df1['XLarge Bags'])
# Out:
# <AxesSubplot:xlabel='XLarge Bags'>

# %% [markdown]
# ### Detecting Skewness

# %%
df1.skew()
# Out:
# AveragePrice    0.227343
# Total Volume    1.616285
# 4046            1.609595
# 4225            1.589596
# 4770            2.120266
# Total Bags      1.789303
# Small Bags      1.773662
# Large Bags      3.029740
# XLarge Bags     1.933999
# year           -2.481862
# dtype: float64

# %%
sns.distplot(df1['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.distplot(df1['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %%
sns.distplot(df1['4046'])
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Density'>

# %%
sns.distplot(df1['4225'])
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Density'>

# %%
sns.distplot(df1['4770'])
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Density'>

# %%
sns.distplot(df1['Total Bags'])
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
sns.distplot(df1['Small Bags'])
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Density'>

# %%
sns.distplot(df1['Large Bags'])
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Density'>

# %%
sns.distplot(df1['XLarge Bags'])
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Density'>

# %%
sns.distplot(df1['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %% [markdown]
# ## Encoding Categorical Columns

# %%
from sklearn.preprocessing import LabelEncoder
categorical_cols = df1.select_dtypes(include=['object']).columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df1[col] = le.fit_transform(df1[col])
    label_encoders[col] = le

# %%
df1.dtypes
# Out:
# Date              int32
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# dtype: object

# %% [markdown]
# #### Key Observation
#
# We have only float64 and int32 type data type after encoding the dataset.

# %% [markdown]
# ### Separating features and labels

# %%
xav=df1.drop('AveragePrice',axis=1)
yav=df1['AveragePrice']

# %%
xav
# Out:
#     Date  Total Volume        4046        4225       4770  Total Bags  \
# 32    43    5338992.15  2786200.82  1654563.98  108561.00   789666.35
# 33    25    6323724.80  3050014.63  2260890.88  115290.95   897528.34
# 34     6    6937095.53  3115937.71  2917083.83  104932.26   799141.73
# 35    66    6013312.36  3163353.08  2021745.62   79259.00   748954.66
# 25    13     913360.72   606650.91   123465.83   18233.51   165010.47
# ..   ...           ...         ...         ...        ...         ...
# 10    40     190846.01    57529.11    56366.66   17531.78    59418.46
# 11    22     178235.75    43325.87    52189.61   19419.57    63300.70
# 12     3     178410.82    46364.75    52893.38   16736.92    62415.77
# 13    64     189131.52    54110.79    53593.58   17495.42    63931.73
# 14    46     182978.30    43116.41    54193.42   16563.91    69104.56
#
#     Small Bags  Large Bags  XLarge Bags  type  year  region
# 32   608751.49   180702.04       212.82     0  2015       8
# ...

# %%
yav
# Out:
# 32    0.98
# 33    0.94
# 34    0.89
# 35    0.90
# 25    0.78
#       ...
# 10    1.39
# 11    1.51
# 12    1.48
# 13    1.47
# 14    1.43
# Name: AveragePrice, Length: 278, dtype: float64

# %%
xav.shape
# Out:
# (278, 12)

# %%
yav.shape
# Out:
# (278,)

# %%
yav.unique()
# Out:
# array([0.98, 0.94, 0.89, 0.9 , 0.78, 0.71, 0.74, 0.7 , 0.68, 0.75, 0.76,
#        0.85, 0.73, 0.84, 0.72, 0.8 , 0.92, 1.52, 1.53, 1.49, 1.48, 1.56,
#        1.62, 1.63, 1.46, 1.19, 1.4 , 1.13, 1.51, 1.39, 0.81, 0.77, 0.79,
#        0.83, 1.03, 1.04, 0.97, 1.34, 1.33, 1.12, 0.95, 1.07, 1.14, 1.1 ,
#        1.18, 1.21, 1.2 , 1.11, 1.09, 1.17, 1.02, 1.01, 1.22, 1.27, 1.28,
#        1.37, 0.91, 0.99, 0.65, 0.58, 0.61, 0.63, 0.67, 0.82, 0.86, 0.93,
#        1.26, 1.45, 1.41, 1.31, 1.29, 1.61, 1.32, 1.38, 1.08, 1.05, 1.06,
#        1.15, 1.36, 1.47, 1.66, 1.57, 1.6 , 1.5 , 1.44, 1.3 , 1.25, 1.23,
#        1.35, 1.68, 0.96, 0.88, 0.87, 1.24, 1.54, 1.64, 1.58, 1.43])

# %%
yav.nunique()
# Out:
# 98

# %% [markdown]
# #### Key Observation
# From the target variable we got to know that it is a problem of continuous regression

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
xav=scale.fit_transform(xav)

# %%
xav.shape
# Out:
# (278, 12)

# %% [markdown]
# ### Spliting the data for training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(xav,yav,test_size=0.20,random_state=43)

# %%
x_train.shape
# Out:
# (222, 12)

# %%
x_test.shape
# Out:
# (56, 12)

# %%
y_train.shape
# Out:
# (222,)

# %%
y_test.shape
# Out:
# (56,)

# %% [markdown]
# ### Model Building

# %% [markdown]
# ### Finding the best random state

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

min_mse = float('inf')
best_rs = 0

for i in range(1, 1000):
    x_train, x_test, y_train, y_test = train_test_split(xav, yav, test_size=0.20, random_state=i)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    mse = mean_squared_error(y_test, pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, pred)
    r2 = r2_score(y_test, pred)
    
    if mse < min_mse:
        min_mse = mse
        best_rs = i
print('Best MSE:', min_mse, 'at random_state', best_rs)
print("MSE:", mse,'at random_state', best_rs)
print("RMSE:", rmse,'at random_state', best_rs)
print("MAE:", mae),'at random_state', best_rs
print("R-squared:", r2,'at random_state', best_rs)
# Out:
# Best MSE: 0.020165077634213793 at random_state 470
# MSE: 0.03876250686352978 at random_state 470
# RMSE: 0.19688196175254294 at random_state 470
# MAE: 0.1525330876874024
# R-squared: 0.44578308932756594 at random_state 470

# %% [markdown]
# #### Key Observations
#
# We got the Bset MSE,RMSE,MAE and R-Squared values at random state 470

# %% [markdown]
# ### Model Improvement:

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Example using Support Vector Regression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

svr = SVR()
svr.fit(x_train_scaled, y_train)
svr_pred = svr.predict(x_test_scaled)
svr_mse = mean_squared_error(y_test, svr_pred)
print("SVR MSE:", mse)
# Out:
# SVR MSE: 0.03876250686352978

# %%
# Example using Multi-layer Perceptron Regression
mlp = MLPRegressor()
mlp.fit(x_train, y_train)
mlp_pred = mlp.predict(x_test)
mlp_mse = mean_squared_error(y_test, mlp_pred)
print("MLPRegressor MSE:", mse)
# Out:
# MLPRegressor MSE: 0.03876250686352978

# %%
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("Decision Tree Regression MSE:", mse)
# Out:
# Decision Tree Regression MSE: 0.02596428571428572

# %%
rf = RandomForestRegressor()
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("Random Forest Regression MSE:", mse)
# Out:
# Random Forest Regression MSE: 0.012685629999999993

# %%
gb = GradientBoostingRegressor()
gb.fit(x_train, y_train)
y_pred = gb.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
print("Gradient Boosting Regression MSE:", mse)
# Out:
# Gradient Boosting Regression MSE: 0.013190613492776495

# %% [markdown]
# ### Cross-Validation Score

# %%
#finding the best cv score for different models
model=[svr,mlp,dt,rf,gb]

scoring = make_scorer(mean_squared_error, greater_is_better=False)

for algorithm in model:

    mse_scores = -cross_val_score(algorithm, xav, yav, scoring=scoring, cv=5)

    mean_mse = mse_scores.mean()

print(type(algorithm).__name__, "MSE:", mean_mse)
# Out:
# GradientBoostingRegressor MSE: 0.0692988933346471

# %% [markdown]
# #### Key Observations
#
# The cross-validated mean squared error (MSE) of 0.06896695852527848 for the GradientBoostingRegressor indicates that the model's performance is relatively better compared to the other algorithms you have evaluated. A lower MSE value indicates that the predicted values are closer to the true values of the target variable.

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

gb = GradientBoostingRegressor()
param_grid = {
    'learning_rate': [0.1, 0.05, 0.01],
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 4, 5]
}

grid_search = GridSearchCV(gb, param_grid, scoring='neg_mean_squared_error', cv=5)
grid_search.fit(xav, yav)

best_params = grid_search.best_params_
best_mse = -grid_search.best_score_

print("Best Hyperparameters:", best_params)
print("Best MSE:", best_mse)
# Out:
# Best Hyperparameters: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100}
# Best MSE: 0.057467980120550766

# %% [markdown]
# #### Key Observations
#
# With these hyperparameters,
#
# Learning Rate: 0.01
# Max Depth: 5
# Number of Estimators: 100
#
# the model achieved a mean squared error (MSE) of 0.057287031783747035.

# %%
# Initialize the GradientBoostingRegressor with the best hyperparameters
best_gb = GradientBoostingRegressor(learning_rate=0.01, max_depth=5, n_estimators=100)

# Retrain the model on the full training dataset
best_gb.fit(x_train, y_train)

y_pred = best_gb.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
print("MSE on Test Set:", mse)
# Out:
# MSE on Test Set: 0.024372221665278467

# %% [markdown]
# ##### Key Observations
#
# The mean squared error (MSE) of 0.02457324901527395 on the test set indicates that the retrained GradientBoostingRegressor model with the optimal hyperparameters is performing well. A lower MSE value suggests that the predicted values are closer to the true values of the target variable.

# %% [markdown]
# ### Comparing the Target Variable with Predicted Data

# %%
new_data = np.array(y_test)
new_predictions = np.array(best_gb.predict(x_test))
Avocado_Average_Price = pd.DataFrame({"Original":new_data,"Predicted":new_predictions}, index=range(len(new_data)))
print(Avocado_Average_Price)
# Out:
#     Original  Predicted
# 0       1.23   1.227811
# 1       0.71   0.878459
# 2       1.08   1.079503
# 3       0.88   0.974343
# 4       0.68   0.871955
# 5       1.44   1.237533
# 6       1.07   1.134199
# 7       1.08   1.128456
# 8       0.98   0.979772
# 9       1.22   1.116045
# 10      1.11   1.120215
# 11      0.65   0.824510
# 12      0.80   0.917940
# 13      0.75   0.918172
# 14      1.50   1.355124
# 15      1.68   1.246616
# 16      0.70   0.878459
# 17      0.90   1.022467
# 18      1.12   1.144545
# 19      0.93   0.935595
# 20      1.31   1.235341
# 21      0.75   0.899071
# 22      0.82   0.959859
# 23      1.05   1.157993
# 24      1.09   1.016905
# 25      1.25   1.254515
# 26      1.02   1.203023
# 27      1.56   1.232688
# 28      1.12   1.022732
# 29      0.88   0.977705
# 30      1.03   1.063963
# 31      1.39   1.332513
# 32      0.75   0.878459
# 33      1.05   1.067799
# 34      1.15   1.126880
# 35      1.33   1.172220
# 36      1.26   1.236276
# ...

# %% [markdown]
# ## Saving The Model

# %%
import joblib
joblib.dump(gb,'gbavacado.obj')
# Out:
# ['gbavacado.obj']

# %% [markdown]
# Finally saving the data using joblib
